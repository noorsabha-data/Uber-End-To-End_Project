# %%
# %sql
SELECT current_catalog(), current_schema();

# %%
# %sql
SHOW CATALOGS;

# %%
# %sql
SHOW SCHEMAS IN uber;

# %%
# %sql
SHOW GRANTS ON CATALOG uber;

# %%
# %sql
SHOW GRANTS ON SCHEMA uber.bronze;
